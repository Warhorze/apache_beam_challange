# %%
import apache_beam as beam
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib

from geopy.distance import geodesic 
from apache_beam.options import pipeline_options
from apache_beam.options.pipeline_options import GoogleCloudOptions
import google.auth
import os

# %%
PROJECT = 'codingchallence'
REGION = 'europe-central2'
BUCKET = 'ml6wra-bucket'


    
START_STATION_COL = "start_station_name"
END_STATION_COL = "end_station_name"

# %%
options = pipeline_options.PipelineOptions([
    "--project", PROJECT,
    "--runner", "InteractiveRunner",
    "--temp_location", f"gs://{BUCKET}/tmp",
    "--region", REGION
])

# Set the pipeline mode to stream the data from Pub/Sub.
options.view_as(pipeline_options.StandardOptions).streaming = True

# Set the project to the default project in your current Google Cloud environment.
# The project is used to create a subscription to the Pub/Sub topic.
_, options.view_as(GoogleCloudOptions).project = google.auth.default()

p = beam.Pipeline(InteractiveRunner(), options=options)

# Set the recording size limit to 1 GB.
ib.options.recording_size_limit = 1e9
ib.options.recording_duration = '10m'
# Out:
#   <style>
#     div.alert {
#       white-space: pre-line;
#     }
#   </style>
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div class="alert alert-info">You have changed recording duration from 60.0 seconds to 600.0 seconds. To allow new data to be recorded for the updated duration the next time a PCollection is evaluated or the pipeline is executed, please invoke ib.recordings.stop, ib.recordings.clear and ib.recordings.record.</div>

# %%
query= """
SELECT start_station_name, end_station_name
FROM bigquery-public-data.london_bicycles.cycle_hire;
"""



rides  = p | 'Create' >> beam.Create([
            {'start_station_name': 'Harper Road, The Borough', 'end_station_name': 'Harper Road, The Borough'},
            {'start_station_name': 'Harper Road, The Borough', 'end_station_name' : 'Wellington Arch, Hyde Park'},
            {'start_station_name': 'Golden Square, Soho','end_station_name': 'Albert Gate, Hyde Park'},
            {'start_station_name': 'Golden Square, Soho','end_station_name': 'Albert Gate, Hyde Park'},
            {'start_station_name': 'Embankment (Savoy), Strand','end_station_name': 'Albert Gate, Hyde Park'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': 'Chepstow Villas, Notting Hill'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': 'Chepstow Villas, Notting Hill'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': 'Chepstow Villas, Notting Hill'}])
                            


total_rides = (
            rides   | 'Get trips column' >> beam.Map(lambda x: (x[START_STATION_COL], x[END_STATION_COL])) 
                    | 'Count elements per trip' >> beam.combiners.Count.PerElement() 
                    | 'map key-value pairs' >> beam.Map(lambda x: (x[0], x[1]))  
                    | "Sort by count" >> beam.transforms.combiners.Top.Of(100, key=lambda x: x[1]) 
                    | "Flatten to dicts" >> beam.FlatMap(lambda x: x)  
    
         )

ib.show(total_rides | "format dataframe" >> beam.Map(lambda x: {START_STATION_COL: x[0][1],END_STATION_COL: x[0][0], "amount_of_rides" : x[1]}))
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_f0ebab6492628cd6d8b9bcc43bffa0c2">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_4304792f53b4bbaa6eeaba5acf5bb0b3" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3")) {
#               dt = $("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3").dataTable();
#             } else if ($("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3_wrapper").length == 0) {
#               dt = $("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'start_station_name'}, {'title': 'end_station_name'}, {'title': 'amount_of_rides'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Chepstow Villas, Notting Hill', 2: 'Green Park Station, Mayfair', 3: '3', 0: 0}, {1: 'Albert Gate, Hyde Park', 2: 'Golden Square, Soho', 3: '2', 0: 1}, {1: 'Albert Gate, Hyde Park', 2: 'Embankment (Savoy), Strand', 3: '1', 0: 2}, {1: 'Wellington Arch, Hyde Park', 2: 'Harper Road, The Borough', 3: '1', 0: 3}, {1: 'Harper Road, The Borough', 2: 'Harper Road, The Borough', 3: '1', 0: 4}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3")) {
#               dt = $("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3").dataTable();
#             } else if ($("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3_wrapper").length == 0) {
#               dt = $("#table_df_4304792f53b4bbaa6eeaba5acf5bb0b3").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'start_station_name'}, {'title': 'end_station_name'}, {'title': 'amount_of_rides'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Chepstow Villas, Notting Hill', 2: 'Green Park Station, Mayfair', 3: '3', 0: 0}, {1: 'Albert Gate, Hyde Park', 2: 'Golden Square, Soho', 3: '2', 0: 1}, {1: 'Albert Gate, Hyde Park', 2: 'Embankment (Savoy), Strand', 3: '1', 0: 2}, {1: 'Wellington Arch, Hyde Park', 2: 'Harper Road, The Borough', 3: '1', 0: 3}, {1: 'Harper Road, The Borough', 2: 'Harper Road, The Borough', 3: '1', 0: 4}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
station_query= """
SELECT latitude, longitude, name 
FROM bigquery-public-data.london_bicycles.cycle_stations;
"""

stations =( p
        | "Get unqiue stations from BigQuery" >> beam.io.ReadFromBigQuery(
            query = station_query,
            use_standard_sql = True,
            gcs_location= f"gs://{BUCKET}/sample_data"
        )

)

ib.show(stations)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_1d1c260ac7861a609d4d5b6452fce451">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 15
#       1 station_query= """
#       2 SELECT latitude, longitude, name
#       3 FROM bigquery-public-data.london_bicycles.cycle_stations;
#       4 """
#       6 stations =( p
#       7         | "Get unqiue stations from BigQuery" >> beam.io.ReadFromBigQuery(
#       8             query = station_query,
#    (...)
#      12
#      13 )
# ---> 15 ib.show(stations)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/utils.py:278, in progress_indicated.<locals>.run_within_progress_indicator(*args, **kwargs)
#     275 @functools.wraps(func)
#     276 def run_within_progress_indicator(*args, **kwargs):
#     277   with ProgressIndicator(f'Processing... {func.__name__}', 'Done.'):
# --> 278     return func(*args, **kwargs)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/interactive_beam.py:831, in show(include_window_info, visualize_data, n, duration, *pcolls)
#     827 pcolls = pcolls - previously_computed_pcolls
#     829 recording_manager = ie.current_env().get_recording_manager(
#     830     user_pipeline, create_if_absent=True)
# --> 831 recording = recording_manager.record(pcolls, max_n=n, max_duration=duration)
#     833 # Catch a KeyboardInterrupt to gracefully cancel the recording and
#     834 # visualizations.
#     835 try:
#     836   # If in notebook, static plotting computed pcolls as computation is done.
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/recording_manager.py:456, in RecordingManager.record(self, pcolls, max_n, max_duration)
#     451   cache_path = ie.current_env().options.cache_root
#     452   is_remote_run = cache_path and ie.current_env(
#     453   ).options.cache_root.startswith('gs://')
#     454   pf.PipelineFragment(
#     455       list(uncomputed_pcolls),
# --> 456       self.user_pipeline.options).run(blocking=is_remote_run)
#     457   result = ie.current_env().pipeline_result(self.user_pipeline)
#     458 else:
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/pipeline_fragment.py:119, in PipelineFragment.run(self, display_pipeline_graph, use_cache, blocking)
#     117   self._runner_pipeline.runner._force_compute = not use_cache
#     118   self._runner_pipeline.runner._blocking = blocking
# --> 119   return self.deduce_fragment().run()
#     120 finally:
#     121   self._runner_pipeline.runner._skip_display = preserved_skip_display
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/pipeline.py:585, in Pipeline.run(self, test_runner_api)
#     583     finally:
#     584       shutil.rmtree(tmpdir)
# --> 585   return self.runner.run_pipeline(self, self._options)
#     586 finally:
#     587   if not is_in_ipython():
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/interactive_runner.py:157, in InteractiveRunner.run_pipeline(self, pipeline, options)
#     150 # The user_pipeline analyzed might be None if the pipeline given has nothing
#     151 # to be cached and tracing back to the user defined pipeline is impossible.
#     152 # When it's None, there is no need to cache including the background
#     153 # caching job and no result to track since no background caching job is
#     154 # started at all.
#     155 if user_pipeline:
#     156   # Should use the underlying runner and run asynchronously.
# --> 157   background_caching_job.attempt_to_run_background_caching_job(
#     158       self._underlying_runner, user_pipeline, options)
#     159   if (background_caching_job.has_source_to_cache(user_pipeline) and
#     160       not background_caching_job.is_a_test_stream_service_running(
#     161           user_pipeline)):
#     162     streaming_cache_manager = ie.current_env().get_cache_manager(
#     163         user_pipeline)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/background_caching_job.py:133, in attempt_to_run_background_caching_job(runner, user_pipeline, options, limiters)
#     123 def attempt_to_run_background_caching_job(
#     124     runner, user_pipeline, options=None, limiters=None):
#     125   """Attempts to run a background source recording job for a user-defined
#     126   pipeline.
#     127
#    (...)
#     131   future cancellation/cleanup is needed.
#     132   """
# --> 133   if is_background_caching_job_needed(user_pipeline):
#     134     # Cancel non-terminal jobs if there is any before starting a new one.
#     135     attempt_to_cancel_background_caching_job(user_pipeline)
#     136     # Cancel the gRPC server serving the test stream if there is one.
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/background_caching_job.py:172, in is_background_caching_job_needed(user_pipeline)
#     169 need_cache = has_source_to_cache(user_pipeline)
#     170 # If this is True, we can invalidate a previous done/running job if there is
#     171 # one.
# --> 172 cache_changed = is_source_to_cache_changed(user_pipeline)
#     173 # When recording replay is disabled, cache is always needed for recordable
#     174 # sources (if any).
#     175 if need_cache and not ie.current_env().options.enable_recording_replay:
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/background_caching_job.py:298, in is_source_to_cache_changed(user_pipeline, update_cached_source_signature)
#     294 # By default gets empty set if the user_pipeline is first time seen because
#     295 # we can treat it as adding transforms.
#     296 recorded_signature = ie.current_env().get_cached_source_signature(
#     297     user_pipeline)
# --> 298 current_signature = extract_source_to_cache_signature(user_pipeline)
#     299 is_changed = not current_signature.issubset(recorded_signature)
#     300 # The computation of extract_unbounded_source_signature is expensive, track on
#     301 # change by default.
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/interactive/background_caching_job.py:348, in extract_source_to_cache_signature(user_pipeline)
#     344 unbounded_sources_as_applied_transforms = utils.unbounded_sources(
#     345     user_pipeline)
#     346 unbounded_sources_as_ptransforms = set(
#     347     map(lambda x: x.transform, unbounded_sources_as_applied_transforms))
# --> 348 _, context = user_pipeline.to_runner_api(return_context=True)
#     349 signature = set(
#     350     map(
#     351         lambda transform: str(transform.to_runner_api(context)),
#     352         unbounded_sources_as_ptransforms))
#     353 return signature
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/pipeline.py:945, in Pipeline.to_runner_api(self, return_context, context, use_fake_coders, default_environment)
#     941 self.visit(ForceKvInputTypes())
#     943 # Mutates context; placing inline would force dependence on
#     944 # argument evaluation order.
# --> 945 root_transform_id = context.transforms.get_id(self._root_transform())
#     946 proto = beam_runner_api_pb2.Pipeline(
#     947     root_transform_ids=[root_transform_id],
#     948     components=context.to_runner_api(),
#     949     requirements=context.requirements(),
#     950     display_data=DisplayData('', self._display_data).to_proto())
#     951 proto.components.transforms[root_transform_id].unique_name = (
#     952     root_transform_id)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/pipeline_context.py:104, in _PipelineContextMap.get_id(self, obj, label)
#     102   self._id_to_obj[id] = obj
#     103   self._obj_to_id[obj] = id
# --> 104   self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105 return self._obj_to_id[obj]
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/pipeline.py:1380, in AppliedPTransform.to_runner_api(self, context)
#    1372 if (not environment_id and
#    1373     (transform_urn not in Pipeline.runner_implemented_transforms())):
#    1374   environment_id = context.get_environment_id_for_resource_hints(
#    1375       self.resource_hints)
#    1377 return beam_runner_api_pb2.PTransform(
#    1378     unique_name=self.full_label,
#    1379     spec=transform_spec,
# -> 1380     subtransforms=[
#    1381         context.transforms.get_id(part, label=part.full_label)
#    1382         for part in self.parts
#    1383     ],
#    1384     inputs={
#    1385         tag: context.pcollections.get_id(pc)
#    1386         for tag,
#    1387         pc in sorted(self.named_inputs().items())
#    1388     },
#    1389     outputs={
#    1390         tag: context.pcollections.get_id(out)
#    1391         for tag,
#    1392         out in sorted(self.named_outputs().items())
#    1393     },
#    1394     environment_id=environment_id,
#    1395     annotations=self.annotations,
#    1396     # TODO(https://github.com/apache/beam/issues/18012): Add display_data.
#    1397     display_data=DisplayData.create_from(self.transform).to_proto()
#    1398     if self.transform else None)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/pipeline.py:1381, in <listcomp>(.0)
#    1372 if (not environment_id and
#    1373     (transform_urn not in Pipeline.runner_implemented_transforms())):
#    1374   environment_id = context.get_environment_id_for_resource_hints(
#    1375       self.resource_hints)
#    1377 return beam_runner_api_pb2.PTransform(
#    1378     unique_name=self.full_label,
#    1379     spec=transform_spec,
#    1380     subtransforms=[
# -> 1381         context.transforms.get_id(part, label=part.full_label)
#    1382         for part in self.parts
#    1383     ],
#    1384     inputs={
#    1385         tag: context.pcollections.get_id(pc)
#    1386         for tag,
#    1387         pc in sorted(self.named_inputs().items())
#    1388     },
#    1389     outputs={
#    1390         tag: context.pcollections.get_id(out)
#    1391         for tag,
#    1392         out in sorted(self.named_outputs().items())
#    1393     },
#    1394     environment_id=environment_id,
#    1395     annotations=self.annotations,
#    1396     # TODO(https://github.com/apache/beam/issues/18012): Add display_data.
#    1397     display_data=DisplayData.create_from(self.transform).to_proto()
#    1398     if self.transform else None)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/pipeline_context.py:104, in _PipelineContextMap.get_id(self, obj, label)
#     102   self._id_to_obj[id] = obj
#     103   self._obj_to_id[obj] = id
# --> 104   self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105 return self._obj_to_id[obj]
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/pipeline.py:1367, in AppliedPTransform.to_runner_api(self, context)
#    1364 # Iterate over inputs and outputs by sorted key order, so that ids are
#    1365 # consistently generated for multiple runs of the same pipeline.
#    1366 try:
# -> 1367   transform_spec = transform_to_runner_api(self.transform, context)
#    1368 except Exception as exn:
#    1369   raise RuntimeError(f'Unable to translate {self.full_label}') from exn
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/pipeline.py:1358, in AppliedPTransform.to_runner_api.<locals>.transform_to_runner_api(transform, context)
#    1354 else:
#    1355   # We only populate inputs information to ParDo in order to expose
#    1356   # key_coder and window_coder to stateful DoFn.
#    1357   if isinstance(transform, ParDo):
# -> 1358     return transform.to_runner_api(
#    1359         context,
#    1360         has_parts=bool(self.parts),
#    1361         named_inputs=self.named_inputs())
#    1362   return transform.to_runner_api(context, has_parts=bool(self.parts))
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/ptransform.py:749, in PTransform.to_runner_api(self, context, has_parts, **extra_kwargs)
#     747 from apache_beam.portability.api import beam_runner_api_pb2
#     748 # typing: only ParDo supports extra_kwargs
# --> 749 urn, typed_param = self.to_runner_api_parameter(context, **extra_kwargs)  # type: ignore[call-arg]
#     750 if urn == python_urns.GENERIC_COMPOSITE_TRANSFORM and not has_parts:
#     751   # TODO(https://github.com/apache/beam/issues/18713): Remove this fallback.
#     752   urn, typed_param = self.to_runner_api_pickled(context)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/core.py:1735, in ParDo.to_runner_api_parameter(self, context, **extra_kwargs)
#    1732   context.add_requirement(
#    1733       common_urns.requirements.REQUIRES_STATEFUL_PROCESSING.urn)
#    1734 from apache_beam.runners.common import DoFnSignature
# -> 1735 sig = DoFnSignature(self.fn)
#    1736 is_splittable = sig.is_splittable_dofn()
#    1737 if is_splittable:
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/common.py:303, in apache_beam.runners.common.DoFnSignature.__init__()
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/common.py:332, in apache_beam.runners.common.DoFnSignature._validate()
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/common.py:390, in apache_beam.runners.common.DoFnSignature._validate_stateful_dofn()
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/userstate.py:281, in validate_stateful_dofn(dofn)
#     278 """Validates the proper specification of a stateful DoFn."""
#     280 # Get state and timer specs.
# --> 281 all_state_specs, all_timer_specs = get_dofn_specs(dofn)
#     283 # Reject DoFns that have multiple state or timer specs with the same name.
#     284 if len(all_state_specs) != len(set(s.name for s in all_state_specs)):
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/userstate.py:248, in get_dofn_specs(dofn)
#     246 if not isinstance(getattr(dofn, method_name, None), types.MethodType):
#     247   continue
# --> 248 method = MethodWrapper(dofn, method_name)
#     249 param_ids = [
#     250     d.param_id for d in method.defaults if isinstance(d, _DoFnParam)
#     251 ]
#     252 if len(param_ids) != len(set(param_ids)):
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/runners/common.py:159, in apache_beam.runners.common.MethodWrapper.__init__()
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/core.py:374, in get_function_arguments(obj, func)
#     372   return f()
#     373 f = getattr(obj, func)
# --> 374 return get_function_args_defaults(f)
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/core.py:394, in get_function_args_defaults(f)
#     390 # TODO(BEAM-5878) support kwonlyargs on Python 3.
#     391 _SUPPORTED_ARG_TYPES = [
#     392     parameter.POSITIONAL_ONLY, parameter.POSITIONAL_OR_KEYWORD
#     393 ]
# --> 394 args = [
#     395     name for name,
#     396     p in signature.parameters.items() if p.kind in _SUPPORTED_ARG_TYPES
#     397 ]
#     398 defaults = [
#     399     p.default for p in signature.parameters.values()
#     400     if p.kind in _SUPPORTED_ARG_TYPES and p.default is not p.empty
#     401 ]
#     403 return args, defaults
#
# File ~/Documents/projects/ml6_challange/.venv/lib/python3.11/site-packages/apache_beam/transforms/core.py:394, in <listcomp>(.0)
#     390 # TODO(BEAM-5878) support kwonlyargs on Python 3.
#     391 _SUPPORTED_ARG_TYPES = [
#     392     parameter.POSITIONAL_ONLY, parameter.POSITIONAL_OR_KEYWORD
#     393 ]
# --> 394 args = [
#     395     name for name,
#     396     p in signature.parameters.items() if p.kind in _SUPPORTED_ARG_TYPES
#     397 ]
#     398 defaults = [
#     399     p.default for p in signature.parameters.values()
#     400     if p.kind in _SUPPORTED_ARG_TYPES and p.default is not p.empty
#     401 ]
#     403 return args, defaults
#
# KeyboardInterrupt:

# %%
## The sql transform doesn't seem to work on my machine.. also the bigquery dataset should first be reduced..
# from apache_beam.transforms.sql import SqlTransform
# query = """
# SELECT
#    a.name as Station1,
#    b.name as Station2,
#    a.latitude as latitude1,
#    a.longitude as longitude1,
#    b.latitude as latitude2,
#    b.longitude. as longitude2
#    FROM
#        `bigquery-public-data.london_bicycles.cycle_stations` a
#   CROSS JOIN     
#        `bigquery-public-data.london_bicycles.cycle_stations` b
#    WHERE
#    a.name != b.name; 
# """
# station_combination =(
#    stations
#    | "Get Combinations" >> SqlTransform(query)
#)

# %%
from geopy.distance import geodesic 
import apache_beam as beam
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib

from apache_beam.options import pipeline_options
from apache_beam.options.pipeline_options import GoogleCloudOptions
import google.auth
import os



stations = p | 'Create' >> beam.Create([
    {'latitude': 51.49859784, 'longitude': -0.096191134, 'name': 'Harper Road, The Borough'},
    {'latitude': 51.50274025, 'longitude': -0.149569201, 'name': 'Wellington Arch, Hyde Park'}
])




pc_with_key = stations | 'Add Key' >> beam.Map(lambda x: ('key', x ))
cross_join = {'pc1': pc_with_key, 'pc2': pc_with_key} | beam.CoGroupByKey()
distance =( 
       cross_join | 'Calculate distance' >> beam.ParDo(CalculateDist())
       | "Create shared key for distance" >> beam.Map(lambda x: ((x[START_STATION_COL], x[END_STATION_COL]),x['distance']))
)

ib.show(distance)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_959e2c2a452d5e7f1250cce076b5da6b">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_6a5e33ea5136aeb19296ab8ad927cdac" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_6a5e33ea5136aeb19296ab8ad927cdac")) {
#               dt = $("#table_df_6a5e33ea5136aeb19296ab8ad927cdac").dataTable();
#             } else if ($("#table_df_6a5e33ea5136aeb19296ab8ad927cdac_wrapper").length == 0) {
#               dt = $("#table_df_6a5e33ea5136aeb19296ab8ad927cdac").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'distance.0'}, {'title': 'distance.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: "('Harper Road, The Borough', 'Harper Road, The Borough')", 2: '0.0', 0: 0}, {1: "('Harper Road, The Borough', 'Wellington Arch, Hyde Park')", 2: '3.7350891558061026', 0: 1}, {1: "('Wellington Arch, Hyde Park', 'Harper Road, The Borough')", 2: '3.7350891558061026', 0: 2}, {1: "('Wellington Arch, Hyde Park', 'Wellington Arch, Hyde Park')", 2: '0.0', 0: 3}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_6a5e33ea5136aeb19296ab8ad927cdac")) {
#               dt = $("#table_df_6a5e33ea5136aeb19296ab8ad927cdac").dataTable();
#             } else if ($("#table_df_6a5e33ea5136aeb19296ab8ad927cdac_wrapper").length == 0) {
#               dt = $("#table_df_6a5e33ea5136aeb19296ab8ad927cdac").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'distance.0'}, {'title': 'distance.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: "('Harper Road, The Borough', 'Harper Road, The Borough')", 2: '0.0', 0: 0}, {1: "('Harper Road, The Borough', 'Wellington Arch, Hyde Park')", 2: '3.7350891558061026', 0: 1}, {1: "('Wellington Arch, Hyde Park', 'Harper Road, The Borough')", 2: '3.7350891558061026', 0: 2}, {1: "('Wellington Arch, Hyde Park', 'Wellington Arch, Hyde Park')", 2: '0.0', 0: 3}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
result = (total_rides_kv, distance) | beam.CoGroupByKey() 
ib.show(result)

# %%
total_rides = (
            rides   | 'Get trips column' >> beam.Map(lambda x: (x[START_STATION_COL], x[END_STATION_COL])) 
                    | 'Count elements per trip' >> beam.combiners.Count.PerElement() 
)
ib.show(total_rides)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_7a97f14a53e196cd4300bb0150dc857b">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_0e0ff8034a1dbeaa37c74c5aebe480c1" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1")) {
#               dt = $("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1").dataTable();
#             } else if ($("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1_wrapper").length == 0) {
#               dt = $("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'total_rides.0'}, {'title': 'total_rides.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: "('Harper Road, The Borough', 'Harper Road, The Borough')", 2: '1', 0: 0}, {1: "('Harper Road, The Borough', 'Wellington Arch, Hyde Park')", 2: '1', 0: 1}, {1: "('Golden Square, Soho', 'Albert Gate, Hyde Park')", 2: '2', 0: 2}, {1: "('Embankment (Savoy), Strand', 'Albert Gate, Hyde Park')", 2: '1', 0: 3}, {1: "('Green Park Station, Mayfair', 'Chepstow Villas, Notting Hill')", 2: '3', 0: 4}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1")) {
#               dt = $("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1").dataTable();
#             } else if ($("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1_wrapper").length == 0) {
#               dt = $("#table_df_0e0ff8034a1dbeaa37c74c5aebe480c1").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'total_rides.0'}, {'title': 'total_rides.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: "('Harper Road, The Borough', 'Harper Road, The Borough')", 2: '1', 0: 0}, {1: "('Harper Road, The Borough', 'Wellington Arch, Hyde Park')", 2: '1', 0: 1}, {1: "('Golden Square, Soho', 'Albert Gate, Hyde Park')", 2: '2', 0: 2}, {1: "('Embankment (Savoy), Strand', 'Albert Gate, Hyde Park')", 2: '1', 0: 3}, {1: "('Green Park Station, Mayfair', 'Chepstow Villas, Notting Hill')", 2: '3', 0: 4}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
ib.show(distance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pc_with_key = stations | 'Add Key' >> beam.Map(lambda x: ('key', x ))
#       2 cross_join = {'pc1': pc_with_key, 'pc2': pc_with_key} | beam.CoGroupByKey()
#       3 distance =(
#       4        cross_join | 'Calculate distance' >> beam.ParDo(CalculateDist())
#       5        | "Create shared key for distance" >> beam.Map(lambda x: ((x[START_STATION_COL], x[END_STATION_COL]),x['distance']))
#       6 )
#
# NameError: name 'stations' is not defined

# %%
class CalculateDistanceAllRides(beam.DoFn):
    def process(self, element):
        key, (rides, distances) = element
        total_distance = 0
        total_rides = 0        
        ride_count = rides[0] if isinstance(rides, list) and rides else None
        distance_value = distances[0] if isinstance(distances, list) and distances else None

        if isinstance(ride_count, (int, float)) and isinstance(distance_value, (int, float)):
            total_distance = ride_count * distance_value
            total_rides =ride_count if isinstance(ride_count, (int, float)) else 0
       
        
        
        yield (key, total_rides, total_distance)

class CalculateDistanceBetweenStations(beam.DoFn):
    def process(self, element):
        _, values = element
        for v1 in values['pc1']:
            for v2 in values['pc2']:
                distance, name1, name2 = calculate_euclidean_distance(v1, v2)
                yield ((name1, name2), distance)


def calculate_euclidean_distance(point1, point2):
    coord1 = (point1['latitude'], point1['longitude'])
    coord2 = (point2['latitude'], point2['longitude'])
    distance = geodesic(coord1,coord2).kilometers
    return distance, point1['name'], point2['name']
    

def format_csv(join_list):
    return ','.join([str(x) for x in join_list])  

     

rides  = p | 'Create Rides' >> beam.Create([
            {'start_station_name': 'Harper Road, The Borough', 'end_station_name': 'Harper Road, The Borough'},
            {'start_station_name': 'Harper Road, The Borough', 'end_station_name' : 'Wellington Arch, Hyde Park'},
            {'start_station_name': 'Golden Square, Soho','end_station_name': 'Albert Gate, Hyde Park'},
            {'start_station_name': 'Golden Square, Soho','end_station_name': 'Albert Gate, Hyde Park'},
            {'start_station_name': 'Embankment (Savoy), Strand','end_station_name': 'Albert Gate, Hyde Park'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': None},
            {'start_station_name': None,'end_station_name': 'Chepstow Villas, Notting Hill'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': 'Chepstow Villas, Notting Hill'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': 'Chepstow Villas, Notting Hill'},
            {'start_station_name': 'Green Park Station, Mayfair','end_station_name': 'Chepstow Villas, Notting Hill'}])
                        
total_rides = (
                rides   | 'Get trips column' >> beam.Map(lambda x: (x[START_STATION_COL], x[END_STATION_COL])) 
                        | 'Count elements per trip' >> beam.combiners.Count.PerElement() 
    )



stations = p | 'Create Stations' >> beam.Create([
    {'latitude': 51.49859784, 'longitude': -0.096191134, 'name': 'Harper Road, The Borough'},
    {'latitude': 51.50274025, 'longitude': -0.149569201, 'name': 'Wellington Arch, Hyde Park'}
])



pc_with_key = stations | 'Add Key' >> beam.Map(lambda x: ('key', x ))
distance = {'pc1': pc_with_key, 'pc2': pc_with_key} \
                        | beam.CoGroupByKey() \
                        | 'Calculate distance' >> beam.ParDo(CalculateDistanceBetweenStations())

result = (
     (total_rides,  distance)
     | "Group by Key" >> beam.CoGroupByKey()
    # | "Explode column" >> beam.Map(lambda x: (x[0],( x[1][0], x[1][1])))
     | "Calculate Total Distance" >> beam.ParDo(CalculateDistanceAllRides())
     #| "Sort by total distances" >> beam.transforms.combiners.Top.Of(100, key=lambda x: x[1]) 
     #| "Flatten to dicts" >> beam.FlatMap(lambda x: x)
     | "Filter None" >> beam.Filter(lambda x: filter_none([x[0][0],x[0][1], x[1],x[2]]))
     | "Rename Columns" >> beam.Map(lambda x: format_csv([x[0][0],x[0][1], x[1],x[2]])) 
     
)



ib.show(result)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_bc0f6303448ccc6bc6e13bd7c1766ac0">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_a997ca41c3b09a9820cc213429fb2566" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_a997ca41c3b09a9820cc213429fb2566")) {
#               dt = $("#table_df_a997ca41c3b09a9820cc213429fb2566").dataTable();
#             } else if ($("#table_df_a997ca41c3b09a9820cc213429fb2566_wrapper").length == 0) {
#               dt = $("#table_df_a997ca41c3b09a9820cc213429fb2566").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'result.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Harper Road, The Borough,Harper Road, The Borough,1,0.0', 0: 0}, {1: 'Harper Road, The Borough,Wellington Arch, Hyde Park,1,3.7350891558061026', 0: 1}, {1: 'Golden Square, Soho,Albert Gate, Hyde Park,0,0', 0: 2}, {1: 'Embankment (Savoy), Strand,Albert Gate, Hyde Park,0,0', 0: 3}, {1: 'Green Park Station, Mayfair,Chepstow Villas, Notting Hill,0,0', 0: 4}, {1: 'Wellington Arch, Hyde Park,Harper Road, The Borough,0,0', 0: 5}, {1: 'Wellington Arch, Hyde Park,Wellington Arch, Hyde Park,0,0', 0: 6}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_a997ca41c3b09a9820cc213429fb2566")) {
#               dt = $("#table_df_a997ca41c3b09a9820cc213429fb2566").dataTable();
#             } else if ($("#table_df_a997ca41c3b09a9820cc213429fb2566_wrapper").length == 0) {
#               dt = $("#table_df_a997ca41c3b09a9820cc213429fb2566").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'result.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Harper Road, The Borough,Harper Road, The Borough,1,0.0', 0: 0}, {1: 'Harper Road, The Borough,Wellington Arch, Hyde Park,1,3.7350891558061026', 0: 1}, {1: 'Golden Square, Soho,Albert Gate, Hyde Park,0,0', 0: 2}, {1: 'Embankment (Savoy), Strand,Albert Gate, Hyde Park,0,0', 0: 3}, {1: 'Green Park Station, Mayfair,Chepstow Villas, Notting Hill,0,0', 0: 4}, {1: 'Wellington Arch, Hyde Park,Harper Road, The Borough,0,0', 0: 5}, {1: 'Wellington Arch, Hyde Park,Wellington Arch, Hyde Park,0,0', 0: 6}])
#               .draw('full-hold');
#           });
#         }
#             </script>
